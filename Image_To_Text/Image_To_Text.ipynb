# %%
import requests

# %%
r = requests.get("https://raw.githubusercontent.com/tesseract-ocr/tessdata/4.00/ind.traineddata", "wb") as file:

with open("users/aaravgoyal/downloads")
# Out:
#   Cell In[6], line 1
#     r = requests.get("https://raw.githubusercontent.com/tesseract-ocr/tessdata/4.00/ind.traineddata", "wb") as file:
#                                                                                                             ^
# SyntaxError: invalid syntax

# %%
! apt install tesseract-ocr libtesseract-dev libmagickwand-dev

from IPython.display import HTML, clear_output
clear_output()

# %%
brew install tesseract
