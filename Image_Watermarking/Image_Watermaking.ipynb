# %%
import Image
import numpy as np
import cv2
import requests
from PIL import Image

# %%
image = Image.open("/Users/aaravgoyal/Downloads/GitHub/KaggleProjectsPython/Image_Watermarking/python.png")
#image = Image.open(requests.get("https://www.aparisguide.com/eiffeltower/eiffel-tower002.jpg",stream=True).raw)
image_logow = image.resize((500,300))
image_textx = image.resize((500,300))
image_logow
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>
